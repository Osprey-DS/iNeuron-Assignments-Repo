# %% [markdown]
# ### Q-13. Write an SQL query to show only odd rows from a table.
#
# ```
#             SELECT
#                 *
#             FROM
#                 employees
#             WHERE
#                 (emp_no % 2) = 1;
#
# ```
# Here i am usining `%` to check the it is `odd` or `even`.
#
# Here is an example...

# %% [markdown]
# ![a7_q.png](attachment:a7_q.png)
#
# Yellow highlited column `emp_no` are has been check for odd or even query..

# %% [markdown]
# ### Q-14. Write an SQL query to clone a new table from another table.
#
# ```
#                     CREATE TABLE
#                         new_table LIKE Original_table;
#
# ```
# By excuting above command it will create a new or clone table like `Original_table` and for inserting the data into cloned table. we have to excute the following query...
#
# ```
#                     INSERT INTO
#                         new_table
#                     SELECT
#                             *
#                     FROM Original_table
# ```
#
# After excuting above query all the data were in `Original_table` it will be pasted on `new_table`.
