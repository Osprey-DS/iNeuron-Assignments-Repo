# %% [markdown]
# ### Q-1. Write an SQL query to print the FIRST_NAME from Worker table after replacing ‘a’ with ‘A’.
#
# ```
#                 SELECT
#                     REPLACE(FIRST_NAME, 'a', 'A')
#                 FROM
#                     Worker;
# ```
#
# Here is an example where i replace my name `'b'` character with `'B'`.
#
# ![my%20name%20charchange.png](attachment:my%20name%20charchange.png)

# %% [markdown]
# ### Q-2. Write an SQL query to print all Worker details from the Worker table order by FIRST_NAME Ascending and DEPARTMENT Descending.
#
# ```
#             SELECT
#                 *
#             FROM
#                 Worker
#             ORDER BY FIRST_NAME ASC,
#                      DEPARTMENT DESC;
#
# ```

# %% [markdown]
# ### Q-3. Write an SQL query to fetch the names of workers who earn the highest salary.
#
# Here is the top 10 higest paying worker from the tabe
#
# ```
#             SELECT
#
#                 first_name, salary
#
#             FROM
#
#                 Worker
#             ORDER BY salary DESC
#             LIMIT 10;
#
# ```
#
# Here is an example, but the query is different because i have to merge two table to obtain the salaries and names.
#
# ![10thhigestsalaries.png](attachment:10thhigestsalaries.png)
