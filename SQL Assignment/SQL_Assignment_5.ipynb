# %% [markdown]
# ### Q-1. Write an SQL query to print details of workers excluding first names, “Vipul” and “Satish” from Worker table.
#
# Here i will use `NOT IN` for excluding the given name
#
# ```
#             SELECT
#                   *
#             FROM
#                 Worker
#             WHERE first_name NOT IN ('Vipul', 'Satish');
#
# ```
#
# Here is an example.
# First i will show some records and then i will exclude two name from the records.
#
# ![first10%20rec.png](attachment:first10%20rec.png)

# %% [markdown]
# Now i will exclude yellow highlited name from the records.
#
# ![exclude%202%20names.png](attachment:exclude%202%20names.png)
#
# Here we can see the first two name is not in the record as it start from emp_no 10003

# %% [markdown]
# ### Q-2. Write an SQL query to print details of the Workers whose FIRST_NAME ends with ‘h’ and contains six alphabets.

# %% [markdown]
# ### Q-3. Write a query to validate Email of Employee.
#
# ```
#         SELECT
#             *
#         FROM
#             Worker
#         WHERE Email LIKE '%@gmail.com'
# ```
