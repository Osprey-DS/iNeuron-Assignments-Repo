# %% [markdown]
# ### 1.	In the sense of machine learning, what is a model? What is the best way to train a model?
#
# Ans>> In the sense of machine learning a Model can be defined as a learned algorithm that can perform the specif task which it is learned. The model learns from past data that we provide it to, and the algorithm we use to create the model finds the pattern from the data and calculates the result from it in the time of performing.
#
# The best way to training a model is to feed it a good quality of data. The more quality of the data would be the more quality of the model. That means the model learns from data, we have to make sure that the quality of the data, also along with that we have to choose a suitable algorithm to fit the data concerning the problem and the data.

# %% [markdown]
# ### 2.In the sense of machine learning, explain the "No Free Lunch" theorem.
#
# Ans>> The main moto of the **‘No Free Lunch’** theorem that we must have to make assumptions before choosing a machine learning algorithm or model. Like a linear model make the assumptions that the data is fundamentally linear. And the distance between the data points and the regressing line is just noise that can be safely ignored.

# %% [markdown]
# ### 3. Describe the K-fold cross-validation mechanism in detail.
#
# Ans>> The cross-validation use to check the performance of the model in unseen data. to use a limited sample to estimate how the model is expected to perform in general when used to make predictions on data not used during the training of the model. In the k-fold-cross-validation, the `k` is denoted that in how many groups the data will be split in to test set and training set, because we use cross validation with a small size of data and we use the same data with resampling.
#
# The main procedure can be this way…
#
# * First, take the dataset.
#
# * Split the dataset into k groups where k is just a number, typically range 5 to 10, depends on the problem and the size of the data.
#
# * Now fro each group split the data into train set and test set to perform the model performance.
#
# * Fit the model in the training set and then test it on that group test set.
#
# * Check the model performance and then repeating the process k times.
#
# Also, the total process(k times) is done automatically and can return the mean value. Of the error and accuracy.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. Describe the bootstrap sampling method. What is the aim of it?
#
# Ans>> Bootstrap sampling methods are sampling a limited size of data with replacement. It is used to determine the aggregating value differs from the population from a sample. We can think bootstrap as a get sample with from s bigger sample, the sample size we can decide. The sampling will occur with replacement with shuffling.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5. What is the significance of calculating the Kappa value for a classification model? Demonstrate how to measure the Kappa value of a classification model using a sample collection of results.
#
# Ans>> The value for kappa can range between 0 -1. A score of 0 means that there is random agreement among raters, whereas a score of 1 means that there is a complete agreement between the raters. However, a score that is less than 0 means that there is less agreement than chance.
#
# #### Example --
# The following data were collected when using a classification model to predict the malignancy of a group of patients' tumors:
#          i. Accurate estimates – 15 cancerous, 75 benign
#          ii. Wrong predictions – 3 cancerous, 7 benign
#                 Determine the model's error rate, Kappa value, sensitivity, precision, and F-measure.
#
#
# Ans>> The confusion matrix can be for this result…
#
# ![image.png](attachment:image.png)
#
#
# `TP  = true positive`,  `TN  = true negative`,  `FP  = false positive`,  `FN  = false negative`
#
# Now I have created the confusion matrix for the problem now from the given problem.
#
#
# * The kappa value – The kappa value can be used in a classification model to measure the model performance. kappa value compare any classifier to the baseline a random classifier
#
# * `Κ  = (accuracy − random accuracy)  /  (1 − random accuracy)`
#
# Where accuracy formula is , accuracy = (TP+TN) / (TP+TN+FP+FN)
#
# And the random accuracy is calculated …
#
# `p1 = (TP+FN) / (TP+FP+TN+FN)`
# `p2 = (TP+FP) / (TP+FP+TN+FN)`
#
# where p1 is the probability of randomly label class from the data by our model,
# and p2 is the probability of making a positive label from data by our model.
#
# now the `random accuracy =  (p1*p2) + {(1−p1) * (1−p2)}`
#
# now for the given data,
#
# `accuracy = (15+75) / (15 + 7 + 3 + 75) = 9/10 = 0.9 or 90%`
#
# `p1 = (15 + 7) / (15+7+3+75) = 22/100 = 0.22`
#
# `p2 = (15+3) / (15+7+3+75) = 18/100 = 0.18`
#
# `random accuracy = (0.22 * 0.18) + (0.78 * 0.82) = 0.0396 + 0.6396 = 0.6792`
# `kappa value (k) = (0.9 – 0.6792) / 0.3208 = 0.6882 or 69% `
#
# #### Why we use Kappa Value:-
# now we can observe that although our model has over 90% accuracy but the kappa value is only 69%, here the kappa value is a more reliable measure than accuracy, This type of behavior can observe that where the positive class has very less amount than a negative class like if our data set have only 10 people have cancer out of 100 people then if our model chooses every people doesn’t have cancer then our model will give 90% accuracy, but our model is predicted all of them don’t have cancer, but our kappa value is 68%, this is the reason we should not use accuracy on a classification problem.

# %% [markdown]
# ### 6. Describe the model ensemble method. In machine learning, what part does it play?
# Ans>> The ensemble method can be considered as the concatenation of multiple models or working multiple models at once. This can be done by adding serval learners or models to create a strong model that can perform better than the individual model will work. The ensemble method can be described by giving an example, One simple DecessionTree algorithm may not be performed very well on a problem, but instead of using one algorithm we can add serval DecessionTree to create a strong model, In practice, we have a model called RandomForest which is very strong model can perform both classification and regression problem(have different algorithms for regression and classification). The RandomForest model is nothing but adding multiple DecessionTree models altogether. This is the main concept of the ensemble method. The main reason to use ensemble methods is getting higher performance and robustness of the model.
#
# In machine learning, if we get some complex problem with a very complex dataset then we can use ensemble methods to achieve a good method when other algorithms will not give us a good result. In that time ensemble method may work better.
#
# There are several ensemble methods, some popular ensemble methods are boosting, bagging, and stacking methods, working methods are slightly different than one.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7. What is a descriptive model's main purpose? Give examples of real-world problems that descriptive models were used to solve.
#
# Ans>> The descriptive model is used in an unsupervised machine learning problem where our main focus is to find the relationship between instances rather than to predict some value or class. In the descriptive model, we group similar instances based on their similarity pattern. A descriptive model finds the logical relationship, capture the requirement of the system, capture the pattern of the instance and group them in a different cluster.

# %% [markdown]
# ### 8. Describe how to evaluate a linear regression model.
#
# Ans>> There are serval way to determine the linear regression model evaluation, but the few most commonly used evaluation process are –
#
# * MAE or Mean Absolute Error – This is calculated by subtracting the original value from the predicted value.  And take their absolute value and then divided by the total number of predictions to calculate the mean. Mae is used when our working number is not in a bigger range,  As this is a cost function that means the smaller the number will be the good is our model.  The close to zero models are good.
# ![image.png](attachment:image.png)
#
#
# * MSE/RMSE – Root Mean Square error – This is also a cost function. And calculated by squaring the difference of prediction and actual value. And then sum all values and then divided by the number of predictions to calculate the mean. This is most used than MAE, because firstly sometimes MSE value can be too big to compare easily. Secondly, MSE is calculated by the square of error, and thus square root brings it back to the same level of prediction error and makes it easier for interpretation. This means it is used when our data range is much higher.
# ![image-2.png](attachment:image-2.png)
#
# * R Square/Adjusted R Square – This is an accuracy function rather than a cost function, the range of this value lies between 0 to 1, the more closer the value to 1 the model is better, and the closer to 0 means the model needs improvement. R Square measures how much variability in the dependent variable can be explained by the model. It is the square of the Correlation Coefficient or R and that is why it is called R Square. R Square is calculated by the sum of squared of prediction error divided by the total sum of the square which replaces the calculated prediction with mean.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 9. Distinguish :
#
# #### 1. Descriptive vs. predictive models
#
# Ans>>  The Descriptive model is more focused on the find the pattern of the data and explain the variability of the instances. The descriptive model is used in an unsupervised machine learning problem where our main focus is to find the relationship between instances rather than to predict some value or class. In the descriptive model, we group similar instances based on their similarity pattern. A descriptive model finds the logical relationship, capture the requirement of the system, capture the pattern of the instance and group them in a different cluster. Overall the Descriptive model works on ‘What is Happen’.
# And in the other side, the predictive model is focused on the find the pattern of the instance to predict the correct value from new similar data. This is the main difference from the descriptive model. The model finds the logical pattern to predict value on the unseen data, the model works on the  ‘What will happen’.
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# #### 2. Underfitting vs. overfitting the model
#
# Ans>> The main problem is encounter when working on dealing with the machine learning model is that Overfitting and Underfitting. These are two measurements that how our model will work on unseen data or new data to predict the value or class.
# Underfitting -  Underfitting is the kind of situation when our model Is too simple as it fails to capture the underlying pattern of the data or fails to capture the logical relationship to perform on the new data. This situation may also arise when our choosing algorithm is not suitable for that specific data and problem, we may choose a more complex algorithm for our problem. If our model is in an Underfitting state also we can say that it has high bias and low variance. The Underfitting model does not work well on training data as well as testing data. If our model is Underfitting then our model needs further improvement.
# Overfitting – Overfitting is the kind of situation when our model is too complex and it finds the relationship well only for the given training data as it worked very well on the training data, but it fails when it comes to the test data or the new data. This type of problem arises when the model is learned too much from his training data and is suited only for the training data, and unable to perform new unseen data. for this type of problem, we can choose a less complex algorithm for the task.
# ![image.png](attachment:image.png)
#
# #### 3. Bootstrapping vs. cross-validation
# Ans>> Bootstrapping and cross-validation are kind of similar things both shuffle a given amount of data and split them into the required group. These are required when we have compared a small amount of data. We can perform bootstrapping cross-validation.
# Bootstrapping - Bootstrap sampling methods are sampling a limited size of data with replacement. It is used to determine the aggregating value differs from the population from a sample. We can think bootstrap as a get sample with from s bigger sample, the sample size we can decide. The sampling will occur with replacement with shuffling.
# Cross-Validation – Cross-validation is also a resampling producer this is used to evaluate the machine learning process when we have a limited amount of data, cross-validation occurs by splitting data into two groups training and testing, to evaluate model performance. we repeat this process multiple times, we can decide how many times this split will occur. The number we called ‘k’, is the reason we also called it k-fold-cross-validation. The grouping occurs with replacement.

# %% [markdown]
# ### 10. Make quick notes on:
#
# #### 1. LOOCV.
#
# Ans>> The LOOCV stand for Leave-One-Out-Cross-Validation, it is also a cross-validation process used to check the model performance in order to find the best model. Here the model is tested on completely unseen data to evaluate his performance, But this loocv is a lengthy process and required lots of time if our data set is big, also it is advisable we should not use this process if we have large data set like we have 5k rows or more than that, we should not use unless we have enough computational power, But using loocv is making sure that we find the good model, that means we used loocv when the main focus is finding best accurate model. As this process every row get the opportunity to test on a model, as it split as many numbers as many rows we have in our data set, and that many time a new model will fit the data to find the best model like if we have 1 thousand rows in our data every row will use for the test and 1 thousand times will fit the model. this is why it takes time to perform and we should not use it when we have a large dataset.
#
# #### 2. F-measurement
#
# Ans>> F-measurement is combined performance matrices for classification model of precision and recall. Precision and recoils are separate performance metric for the classification model. as the precision tells us how much positive class is correctly predicted and the recoil tell us how much positive class is predicted within the total positive class in our dataset, but the f-measurement or f-score give us overall performance measure the range is 0 to 1, this is an accuracy function, not a cost function, means so the greater the number will be the more good result, but this is not used that much in used case because, in a classification problem, we need to focus either precision or recall rather than overall, but it completely depends on the problem in our hand.
#
# ![image-4.png](attachment:image-4.png)
#
# #### 3. The width of the silhouette
#
# Ans>> The silhouette represents how well the data is fitted in different is own cluster or group, this is can be found in unsupervised machine learning where we group similar instance in different groups based on their similarity. And the silhouette technique provides a graphical technique for representation of how well each object has been classified. The silhouette value is a measure of how similar an object is to its cluster compared to other clusters, The silhouette value ranges between −1 to +1, where a high value indicates that the object is well matched to its own cluster and poorly matched to others clusters. If most objects have a high value, then the clustering configuration is appropriate. If many points have a low or negative value, then the clustering configuration may have too many or too few clusters.
#
#
# #### 4. Receiver operating characteristic curve
#
# Ans>> The Receiver operating characteristics curve or the roc curve is one of the great model performance metrics for the classification problem, As the name suggests we plot a curve and from the plot, e can decide our model performance. or we also have a roc score that is also accuracy score can tell us how good our model is. The roc curve plot true positive rate vs false positive rate. To plot the roc curve we need to calculate true positive rate or tpr and false positive rate or fpr for our model.
# ![image-3.png](attachment:image-3.png)
#
# The above two curve randomly two different model.The left side curve represent a bad model as the curve is not fitted to the left upper corner, and the Right side plot represent a good model as his curve is more fitted to the left upper corner.
