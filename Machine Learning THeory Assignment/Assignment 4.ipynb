# %% [markdown]
# ### 1.What are the key tasks involved in getting ready to work with machine learning modeling?
# Ans>> There are many tasks are involved in the  creating of machine learning model
# And we have to focus on every task to make a better model. The key tasks can be following
# Collecting the data -  data can become from many ways from database or website or in file format. We have to collect the appropriate amount and relevant data for our project to make a better model.
# The second task can be data observing and cleaning. What data we just collect we have to observe thoroughly the data and make some assumptions in order to choose machine learning algorithms. Then we have to clean the data, the data can be very messy and we can not feed that data to the model. Also, machine learning models or algorithms can only work with numerical numbers it can’t work with a word so we have to take care of that. We have to perform label encoding for that problem.
# When creating the model we have to notice that the model is building ideally means that the model is not underfitting or overfitting for that we need to do hyperparameter tuning or we can replace the model with another more complex or less complex, depends on the problems.

# %% [markdown]
# ### 2. What are the different forms of data used in machine learning? Give a specific example for each of them.
#
# Ans>> There are main four data forms in machine learning
# Numerical Data – The most common type of data that are used in machine learning although any machine learning model only can wors with the numerical data type. These are numerical features like someone's age, product measurement, or anything with numerical measurement.
#
# Categorial Data – Although in real-life problem data comes with many different types of forms, categorical data can be someone's name or any product name, but machine learning model can not work with them, we have to perform converting approaches to convert them to numerical representations so it can work with a model. Like there are many converting options, one-hot-encoding, and many more.
#
# Time Series Data – This one is one of the most important data forms for time series forecasting models like predicting stock price or predicting the weather. There this type of data form is more important. It comes with the date-time format, or if not then we can convert them easily to date-time format. The main benefit of using this type of data is it can directly work with some machine learning model so we can predict the date or time directly.
# Text Data – Text data can be any word or comment that is come with the data, mostly we can see this form of data in case of doing NLP problems where we are most likely to predict the user sentiment by observing their comments or his typing feedback written in their own speaking languages.

# %% [markdown]
# ### 3. Distinguish:
#
# #### 1.	Numeric vs. categorical attributes
# Ans>> Numerical attributes -  any measurable quantity can be numerical attributes, those that come with the numerical number are considered as numerical attributes.
# Categorial attributes – These come in the form of words that can be written any language.
# ![image.png](attachment:image.png)
#
# #### 2.	Feature selection vs. dimensionality reduction
# Ans>> Feature selection is the choice's most valuable and useful feature in our machine learning model. The data we collect there can come with many features and we may not need all of them for creating the model. In that time we choose some specific feature based on some measurements of that feature which are the most useful feature or whose are putting good impact on our model we keep them only and remove others useless features from the training set.
# Dimensionality Reduction – It is a technique to reduce the dimensions of our model. The dimensions mean in the machine learning model that the data we have basically in tabular form means that have many columns and lots of rows. Sometimes we get data that have many amounts of columns that are too difficult to handle and this can put some bad impact on the model, The more columns have means high dimensionality. We have some very useful approaches that can solve this problem without losing any feature measurements or pieces of information from the data sets like PCA or principal component analysis is the most common and effective way to reduce feature dimensions.

# %% [markdown]
# ### 4. Make quick notes on any two of the following:
#
# #### 1. The histogram
#
# The histogram is used to visualize continuous data or continuous numbers in our data set, it is more likely to look like a bar graph but it shows us the distribution of the measurement. The one specific bins show us that value range in the datasets. One histogram can have many bins with respect to the specific data range.
# ![image.png](attachment:image.png)
#
# #### 2. Use a scatter plot
#
# Scatter plots are only used to plot two numerical data. It is mainly used to show the relation between two numerical variables or to observe the correlation between them. The data points represent are in small dots in the graph. Each dots are a single observation or single row value from the datasets.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 5. Why is it necessary to investigate data? Is there a discrepancy in how qualitative and quantitative data are explored?
# Ans>> It is vast necessary or check every feature or column in our data before creating the model. Because the data is all that we have and the model performance will depend on the data. That for we should thoroughly investigate the data check for every detail and range of the data and clean them as per required for our problem.
# There is a discrepancy between qualitative and quantitative data we have different approaches to observe them, we have to use different graphs or plots to observe qualitative and quantitative data for qualitative data we can use bar graphs, and for quantitative data, we can use scatter plots, line graph.

# %% [markdown]
# ### 6. What are the various histogram shapes? What exactly are ‘bins'?
# Ans>> Varias Histogram shape means the shape of data distributions shape, the data distribution can mainly occur three types of shapes, `Normal`, `Right Skewed`, and `Left skewed`. Normal shape occurs when we have a normal distribution of our data, the distribution shape is right-skewed means most of the data are in the smaller range are living lower range or right side of the graph, that is why the distribution shape is right-skewed. And in another side, if most of the data are living in a higher range or the left side of the graph then the graph will look left-skewed.
#
# Bins – There can be lots of bins in our histogram and the number of bins completely depends on the data range. One single bin refers to a specif data range from the data. Or we can consider bins are equally spaced interval from the data. E.g if our data set is consisting data numbers from 1 to 100 and if we use 10 bins to plot the data then one bin will have 10 interval range in the plotted histogram.
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### 7. How do we deal with data outliers?
# Ans>> Data outliers mean when some data points are too far from our regular data range which we are called outliers. There is serval way to solve data outliers, the basic and most used approaches is data transformation or data scaling, scaling the data can be a better way to handle data outliers. We can do log transformation, standard scaling, and many more scaling options we have.
#
# In the second approach we can remove outlier data from our data set, at first we can check the data basic range from the box plot, and then we can remove those outliers that are not In the normal data range.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8. What are the various central inclination measures? Why does mean vary too much from the median in certain data sets?
#
# Ans>> There are main 3 central inclination measures,
#
# * Mean – The mean is the normal average or arithmetic mean which is calculated by summing all the numbers and divided by the number of occurrences of each number in our data set.
#
# * Median – The median is the middle value of our data set, to find the median we have to reorder our data set from lowest to largest then the middle term will be the median value, if summing elements occurring number is even then we can choose middle two number and get the average of these two numbers.
#
# * Mode – the mode is simple, the most occurring number in our data set. That is called mode.
# If we have data set and some number is repeating multiple times and if we can observe no other number has appeared much that time then that repeated number is mode.
#
# The observing case can be found when our data has outliers. The mean is completely dependent on our data range because in the time of calculation we consider all the numbers including outliers. And median is just a middle number from our data set, outliers do not put any effect on the median. We can observe from a simple example
#
# that if we have data like- 2,1,4,3,5,7,6,55,77
#
# from the data, we can find the mean of the data is around 17, and the median is 5. The difference is quite high, now if we close look at the data we can find two outliers 55 and 77 those are not from the usual range of our data, our data usual range is 1 to 7 where most of the numbers has appeared and if we remove those two outliers then our new data will become 1,2,3,4,5,6,7. I did the ordering also. Now again if we determine the mean then the mean will be 4, and the median will be 4. Both are the same. Just for the outliers, the difference was more. But if we consider the median then the previous median was 5 which is relatively close to the new median, in this way we can see the effect of median and mean vary too much for the unstructured data set.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 9. Describe how a scatter plot can be used to investigate bivariate relationships. Is it possible to find outliers using a scatter plot?
#
# Ans>> For checking relationships between two numerical variables we use a scatter plot. This is the simplest way to analyze bivariate variables. In scatter plot, we two-variable into different axis x and y and we can thoroughly observe the trends of these two variables, which one behaving with other. There are dots in our scatter plot, that every plot describes every instance or every single data point. From one point we can check the x and y value for that particular point and we can get the idea for behavior to each other.
# For finding the outliers we have to find the slop line or the regression line, this regression line is nothing but the original relationship between two variables, if the data point is too far from the regression line then we can say those points are outliers. All the data points are should be plotted on the regression line. But for the noise of our data set not points will be plotted on the line but close to the line.

# %% [markdown]
# ### 10. Describe how cross-tabs can be used to figure out how two variables are related.
# Ans>> A cross tab is showing the relationship between two or more variables, it is also called as contingency table. It is table in matrix format that display the multivariate frequency distribution of the variable. It can provide a basic picture of interrelation between two varuiable and can helps us find relation between them.
#
# We can take an example of 100 people mixed with male and female to find a certain person has the disease or not. Now the regular table will not help us that much to find the relation between the disease and gender, but if we plot cross tab table then it will help us to find and we can easily spot the difference.
# ![image.png](attachment:image.png)
