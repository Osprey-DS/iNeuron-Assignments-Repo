# %% [markdown]
# ### 1. What is the concept of supervised learning? What is the significance of the name?
#
# Ans>> The concept of supervised learning is we create a model which can do a specific type of work that we are trained or learned the model to do it. The Supervised is the name for it is done or the training is done is under the supervision of human or us. We do that by providing the questions and answer at the same time to the model to learn. So the model can see the question and answer at the same time and can learn from it.
#
# Technically the supervised learning is we provide the model the data or instance with the labels or the target value for learning, so the model can find the underlying structure of data that we provide to it. This is the main concept of supervised machine learning data, this is more like teaching children, if we want a kid to familiar with some animal, then the best way to buy an animal picture book and then show the kid the animal picture from the book and tell them which one Tiger or Lion, then the kid will learn from those pictures so after if we asked them to name the animal by showing the picture, they can recognize,
#
# Now here is a thing, how the kid will remember that is not our concern, some kid can memorize by animal color, size, or by looking some other, maybe a kid can recognize a tiger from its zigzag color and can tell this is Lion by looking at his mane.

# %% [markdown]
# ### 2. In the hospital sector, offer an example of supervised learning.
#
# Ans>> In the hospital sector the supervised machine learning can be used in many cases like Diseases detection based on the patient's health report like patient's blood pressure, sugar label, and other reports, based on this report we may have many more data with lots of patient report in the hospital sector,
#
# and we can use this pre available report to use make model and based on that model we can predict the new patient is having a particular disease or not.
#
# Another use case of the supervised machine learning model is to recognize diseases from an x-ray image, this can be done from the deep learning process. It is used to find tumors present in a patient’s body.
# Also, machine learning is helping patients or us to get better know for our health, also we can get our health report by providing some information.

# %% [markdown]
# ### 3. Give three supervised learning examples.
#
# Ans>> The few Supervised Learning examples are…
#
# **House Price Prediction** – This is the most common example of a supervised learning model, This is a regression machine learning model where we are calculating a continuous value. we have to collect some data regarding some house for a specific place, and the information can be house size, the number of rooms, how many bedrooms have, geographical place signature, along with the house price, then we can build a model with this information, we can provide the feature or the information we have along with the price, so the model can learn or capture the relation between the feature our house has and it’s price, The model will learn this way, it is more likely to be the high price of a house which has more number of rooms, compared to few numbers of rooms. In this way, we can use the model by giving some features and ask to predict the price.
#
#
# **Recognize Class** – The other type of machine learning model different from a regression that is a classification problem, here we also provide the model some features, but here we try to predict to some label and class not any continuous number like house price or car price. The number of the label can be two or more than two can be present in our data, and we have to predict that label from the feature like we can have some data of some customer in the banking sector, now if the customer seeking a loan, we can check the customer is reliable or not, he will pay back the loan amount or not, we can check that from machine learning model, by his past behavior. Or his bank statement. We have some data from the previous customer who have the bank statement and he will return or not.
#
#
# **Spam Detection** – Another classification problem can be our mail spam filtering system, we previously create the model with some word that is used to be on spam messages, like ‘you win 1 million’ , Win a car’, ‘95% off’, Now if our message has these sentences then we can put them into the spam folder.

# %% [markdown]
# ### 6. Briefly describe the SVM model.
#
# Ans>> The support vector machine or SVM is a supervised machine learning algorithm, It is very sufficient for both classification and regressing problems, but in the case of classification problems it is strictly binary classification algorithms. The SVM model is efficient for the small and medium-size data set, it may not perform very well on big-size datasets. But it is capable to handle very complex data.  The support vector machine is worked on by dividing the two classes positive and negative classed by creating a boundary line, this boundary line is called Hyperplane. This line separates two classes.
#
# ![image.png](attachment:image.png)
#
# But in the algorithm, there are a total of 3 decision boundary is present in the model. one is the hyperplane which is the main decision boundary and two marginal boundaries which is pass to the nearest one point on both side or in both classes.
# There is a distance between both marginal lines to the hyper line, the length of the distance is can be defined by the model quality, the more the distance will be the more generalized the model will be, which means the good model will be.
# As in the above picture, two classes are there one red and the other is blue, one solid line side is going through between them that is called hyperplane. And two dotted lines pass by touching two classes is called marginal plane, the marginal plane passes through at least one or multiple data points in both sides. The SVM algorithm is required scale dataset, it is best practice to scale our data with MinMax scaler or perform Normalization before passing the data to the SVM model. as it is working on the value or the magnitude of the feature, it is very sensitive to the feature scale. This is the main concept of the Support Vector Machine algorithm.

# %% [markdown]
# ### 7. In SVM, what is the cost of misclassification?

# %% [markdown]
# ### 8. In the SVM model, define Support Vectors.
# Ans>> In order to construct the marginal line on both side of the class and in between the hyperplane the two marginal line pass-through data points to make the line, this data point can be more than one on both side if they are staying in parallel position, these data points are called support vectors, The reason behind the name is these data points support the marginal line and can be the reason to draw the marginal line at that position. In the picture the support vectors are shown.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 9. In the SVM model, define the kernel.
#
# Ans>> The SVM kernel is some mathematical function that is defined as the kernel of SVM. It is required for when we have non-linear data and a straight line can not separate two-class, in that time we need to transform the data in another form, an example can be, if we have some non-linear two-dimensional data, and then we can transform the data using a kernel function to convert it to higher dimensional data and then SVM model can be separate the classes. The kernel function can be different types like linear kernel, non-linear kernel, polynomial kernel, radial basis function or RBF for sort, sigmoid.

# %% [markdown]
# ### 10. What are the factors that influence SVM's effectiveness?
#
# Ans>> There are some factors that can be varied to the performance of the SVM model. we can optimize our model
# The C parameter – This parameter is defining the marine distance from the hyperplane. How much the narrower or wider the marginal distance will be as per our problem and based on the performance of our model we can change the distance by controlling the C parameter,
#
# The smaller value of C will be the wider the distance will be, and for the larger value of C the distance will be very smaller. Now very smaller distance of marginal point to the hyperplane can be Overfit our model. in that case we have to reduce the C value to overcome the problem. The narrower the distance is, that is called hard margin, and the wider the distance is called soft margin.
#
# The below picture shows the effect of the **C parameter**.
#
# ![image.png](attachment:image.png)
#
# **Kernel** – Choosing the best kernel for our problem depends on our problem. Not all the time linear kernels will work best with our problem, we have to go through some experiments by selecting different kernels, The choice of the kernel very much depends on the model performance. If our data is non-linear then we should go for a non-linear kernel, and so on.
# The below picture shows how the kernel can change the dimensions of the data, after that the data can find a linear decision line.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 11. What are the benefits of using the SVM model?
#
# Ans>> The SVM model wors in the smaller size and medium size of the data
#
# The SVM model works well when the separation between two classes is very clear and very clearly linearly separatable.
#
# The SVM model is best in high-dimensional space.
#
# The SVM model can be memory efficient.

# %% [markdown]
# ### 12.  What are the drawbacks of using the SVM model?
#
# Ans>> The SVM model works very poorly with large datasets.
#
# The SVM model can not be very efficient when there is noise in the dataset.
#
# As the SVM model just put the data points two sides of the hyperplane and marginal plane there is no probabilistic explanation for the classification.

# %% [markdown]
# ## 13. Notes should be written on
#
# #### 1. The kNN algorithm has a validation flaw.
# Ans>> The knn validation is used for choosing the ‘K’ value for the algorithms. The ‘k’ value can be dependent on the model performance. in order to get the best of from the model we need to choose a better ‘k’ value,
#
# #### 2. In the kNN algorithm, the k value is chosen.
# Ans>> The ‘k’ value can be dependent on the model performance. the value is chosen like 3, 5, 7, like this, we may need to cross-validation to find best ‘k’ value for our specific problem,
# The notable things here we have to choose the ‘k’ value and odd number, without an odd number the model will be confused sometimes, as the knn algorithms work it find the nearest neighbour for our given data point, and then it finds an equal number of neighbours like 2 from one class and 2 from another class, then it will be confused and may not perform well. And if we choose some odd number then it can easily define the majority of a class.
#
# #### 3. A decision tree with inductive bias
# Ans>> The inductive bias is when we assume some condition on the outcome result. we can define the inductive bias is the set of assumptions that together with the training data, deductively justify the classifications assigned by the learner to future instances.
#
#
# #### 14. What are some of the benefits of the kNN algorithm?
# Ans>> It is simple to understand the core algorithm and simple to implement.
# It works well in noisy data
# It becomes very efficient when the training size is large.
#
#
# #### 15. What are some of the kNN algorithm's drawbacks?
# Ans>> We have to choose the ‘k’ value which can be a very difficult task sometimes.
# This algorithm is computation expensive.

# %% [markdown]
# #### 16. Explain the decision tree algorithm in a few words.
# Ans>> The decision tree algorithm are can be considered a supervised machine learning algorithm that used graphically organized information about possible options, chances, and values,  decision tree can construct some condition based on the given feature, and based on that condition it tries to predict the class from given features. It is can be used for both classification and regression problems. And the decision tree algorithms used the binary tree to perform the split feature to separate the classes from the data. The underlying working principle is not very complicated for the decision tree. The algorithm tries to solve the problem,  by using tree representation algorithms. Each node inside the tree corresponds to an attribute, and each leaf node corresponds to a class label.
#
# ![image.png](attachment:image.png)
#
# The Decision tree algorithms work better on binary classification, althoug it used on multile clasification problem also regression proble.

# %% [markdown]
# ### 17. What is the difference between a node and a leaf in a decision tree?
#
# Ans>> In the decision tree the node are can be considered the branches of the tree on in technical it is the features from the data, and the leaf is the class or the outcomes or the bottom node.
#
# IN this picture the node and leaf node are clearly explained
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 18. What is a decision tree's entropy?
#
# Ans>>  The requirement of entropy is to take the right feature for starting the split of the decision tree or based on which feature we first split the tree, for that entropy is required. Technically the entropy is helped us to measure of the purity of the split of the decision tree.
#
# The value of entropy is between 0 to 1. The entropy is 1 means the split is completely impure and the o entropy means is completely pure. We generally choose the leaser entropy value for the feature and take that feature set.

# %% [markdown]
# ### 19. In a decision tree, define knowledge gain.
#
# Ans>> The entropy is not working alone to decide the best split among all the features we have. The information gain also called knowledge gain is calculated by doing permutation and combination of all features and doing the subset sampling. Which structure has greater information gain value, that structure is taking for final model creation. The information gain is very important to split the tree based on the features we have, although this whole process is done automatically by the algorithm. It calculates all the possible tree structure by doing permutation and combination of feature and calculate information gain, and take the highest values to select the structure.
#
# The detailed formula for the information gain of decision tree
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 20. Choose three advantages of the decision tree approach and write them down.
# Ans>>
# * The decision tree algorithm is easy to understand, and for implementing a decision tree algorithm almost no math concept is required.
#
# * Almost no data preprocessing is required for the decision tree algorithm like scaling the feature or categorical encoding.
#
# * Missing value does not put any effect on the model performance.

# %% [markdown]
# ### 21. Make a list of three flaws in the decision tree process.
#
# Ans>>
# * The decision tree model is very unstable, a small change in data can change a large amount of model structure and performance.
#
# * As it is finding the right tree structure by calculating information gain, it takes a much longer time to train. As it is a more time-consuming process
#
# * Although a decision tree can be used for a regression problem, it is very insufficient for a regression problem.
